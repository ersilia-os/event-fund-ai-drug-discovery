# %% [markdown]
# <a href="https://colab.research.google.com/github/ersilia-os/event-fund-ai-drug-discovery/blob/main/notebooks/session3_skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 3
#
# In this session, we will use the Ersilia Model Hub to access a suite of AI models for Absorption, Distribution, Metabolism, Excretion and Toxicity activities, [ADMETLab](https://admetmesh.scbdd.com/).
#
# *Disclaimer: ADMETLab2.0 is provided as a web-based server, therefore molecules are submitted to a third party browser, which compromises its use for IP-sensitive data. In this exercises we will be using ADMETLab 2.0. The Ersilia Model Hub also contains models from ADMETLab1.0, which run on user's local system and do not post data to third party servers.*

# %% [markdown]
# # Dataset
#
# Information about which data we will use in the session

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load molecules
import pandas as pd

df = pd.read_csv("drive/MyDrive/h3d_ersilia_ai_workshop/data/session3/session3_compounds.csv")
# Out:
# Running cells with 'Python 3.10.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
df
# Out:
#               compound                                         CAN_SMILES
# 0              Quinine              C=CC1CN2CCC1CC2C(O)c1ccnc2ccc(OC)cc12
# 1          Chloroquine                  CCN(CC)CCCC(C)Nc1ccnc2cc(Cl)ccc12
# 2          Amodiaquine             CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O
# 3  Desethylamodiaquine                 CCNCc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O
# 4           Artemether                COC1OC2OC3(C)CCC4C(C)CCC(C1C)C24OO3
# 5         Lumefantrine  CCCCN(CCCC)CC(O)c1cc(Cl)cc2c1-c1ccc(Cl)cc1C2=C...
# 6           Amlodipine    CCOC(=O)C1=C(COCCN)NC(C)=C(C(=O)OC)C1c1ccccc1Cl
# 7           Nifedipine  COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=...
# 8            Ritonavir  CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)...

# %%
smiles = df["CAN_SMILES"].tolist()

# %% [markdown]
# # Ersilia Model Hub
#
# First, we need to install the Ersilia Model Hub in this Colab notebook and fetch the ADMETLab2.0 (eos2v11 or admetlab-2)

# %%
#@title The Ersilia Model Hub
#@markdown Click on the play button to install Ersilia in this Colab notebook.

# %%capture
# %env MINICONDA_INSTALLER_SCRIPT=Miniconda3-py37_4.12.0-Linux-x86_64.sh
# %env MINICONDA_PREFIX=/usr/local
# %env PYTHONPATH={PYTHONPATH}:/usr/local/lib/python3.7/site-packages
# %env CONDA_PREFIX=/usr/local
# %env CONDA_PREFIX_1=/usr/local
# %env CONDA_DIR=/usr/local
# %env CONDA_DEFAULT_ENV=base
# !wget https://repo.anaconda.com/miniconda/$MINICONDA_INSTALLER_SCRIPT
# !chmod +x $MINICONDA_INSTALLER_SCRIPT
# !./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# !python -m pip install git+https://github.com/ersilia-os/ersilia.git
# !python -m pip install requests --upgrade
import sys
_ = (sys.path.append("/usr/local/lib/python3.7/site-packages"))

# %%
# fetch admetlab2
# !ersilia fetch eos2v11
# Out:
# ⬇️  Fetching model eos2v11: admetlab-2
# 👍 Model eos2v11 fetched successfully!

# %%
from ersilia import ErsiliaModel

model = ErsiliaModel("eos2v11")
model.serve()
output = model.predict(input=smiles, output="pandas")
model.close()

# %%
output
# Out:
#                            key  \
# 0  LOUPRKONTZGTKE-UHFFFAOYSA-N
# 1  WHTVZRBIWZFKQO-UHFFFAOYSA-N
# 2  OVCDSSHSILBFBN-UHFFFAOYSA-N
# 3  VRXFDHAGFYWGHT-UHFFFAOYSA-N
# 4  SXYIRMFQILZOAM-UHFFFAOYSA-N
# 5  DYLGFOYVTXJFJP-UHFFFAOYSA-N
# 6  HTIQEAQVCYTUBX-UHFFFAOYSA-N
# 7  HYIMSNHJOBLJNT-UHFFFAOYSA-N
# 8  NCDNCNXCDXHOMX-UHFFFAOYSA-N
#
#                                                input   LogD   LogP Pgp-inh  \
# 0              C=CC1CN2CCC1CC2C(O)c1ccnc2ccc(OC)cc12  2.446  2.719   0.965
# 1                  CCN(CC)CCCC(C)Nc1ccnc2cc(Cl)ccc12  3.723  4.511   0.752
# 2             CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O  3.993  4.714   0.897
# 3                 CCNCc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O  3.441  4.098   0.694
# 4                COC1OC2OC3(C)CCC4C(C)CCC(C1C)C24OO3  3.149  3.333   0.099
# 5  CCCCN(CCCC)CC(O)c1cc(Cl)cc2c1-c1ccc(Cl)cc1C2=C...  4.679  7.612     1.0
# 6    CCOC(=O)C1=C(COCCN)NC(C)=C(C(=O)OC)C1c1ccccc1Cl  2.445  2.104   0.501
# 7  COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=...  2.773  2.384   0.968
# 8  CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)...  4.592    4.5   0.991
#
#   Pgp-sub    HIA F(20%) F(30%)  Caco-2  ...  MCE-18 Natural Product-likeness  \
# 0   0.164  0.027  0.007  0.003   -4.61  ...  73.138                    0.831
# 1   0.985  0.002  0.069  0.013  -4.545  ...    24.0                   -0.891
# 2   0.952  0.003  0.025  0.004  -4.964  ...    17.0                   -0.907
# 3   0.147  0.004  0.015  0.842  -5.084  ...    16.0                   -0.595
# 4   0.001  0.002  0.002  0.032  -4.695  ...    90.0                     3.83
# 5   0.995  0.002  0.009  0.327  -5.847  ...    72.0                   -0.599
# 6   0.185  0.002  0.015  0.004  -4.914  ...  47.069                   -0.736
# 7   0.023  0.004  0.594  0.673  -4.655  ...  50.783                   -1.096
# 8   0.684  0.961  0.007  0.496  -5.228  ...    54.0                   -0.618
#
#   Alarm_NMR  BMS Chelating PAINS  Lipinski    Pfizer       GSK GoldenTriangle
# 0       2.0  0.0       0.0   0.0  Accepted  Accepted  Accepted       Accepted
# 1       0.0  0.0       0.0   0.0  Accepted  Rejected  Rejected       Accepted
# 2       3.0  0.0       0.0   1.0  Accepted  Rejected  Rejected       Accepted
# 3       3.0  0.0       0.0   1.0  Accepted  Rejected  Rejected       Accepted
# 4       0.0  1.0       0.0   0.0  Accepted  Rejected  Accepted       Accepted
# 5       0.0  0.0       0.0   0.0  Rejected  Rejected  Rejected       Rejected
# 6       1.0  0.0       0.0   0.0  Accepted  Accepted  Rejected       Accepted
# 7       2.0  0.0       0.0   0.0  Accepted  Accepted  Accepted       Accepted
# 8       1.0  0.0       0.0   0.0  Rejected  Accepted  Rejected       Rejected
#
# [9 rows x 89 columns]

# %%
output.to_csv("drive/MyDrive/h3d_ersilia_ai_workshop/data/session3/admet_prediction.csv", index=False)
